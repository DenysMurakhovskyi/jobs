# %%
import pandas as pd

# %%
t1 = pd.read_csv('IT_wordcloud_contribution.csv')

# %%
t2 = pd.read_csv('IT_wordcloud_contribution_idf.csv')

# %%
t1['rating_1'] = range(1, len(t1) + 1)

# %%
t2['rating_2'] = range(1, len(t2) + 1)

# %%
t1.drop('value', axis=1).merge(t2.drop('value', axis=1))
# Out:
#                               word  rating_1  rating_2
# 0                       consulting         1         2
# 1                productmanagement         2         1
# 2              informationsecurity         3        10
# 3            stakeholdermanagement         4         3
# 4                            agile         5         6
# 5                   decisionmaking         6         8
# 6             businessintelligence         7         4
# 7                             ssas         8         5
# 8                          outlook         9         9
# 9                      datascience        10         7
# 10                  datamanagement        11        13
# 11                           visio        12        15
# 12                      statistics        13        19
# 13                       marketing        14        16
# 14                       analytics        15        21
# 15                      javascript        16        11
# ...

# %%
Сильно снизились: information security, statistics, analytics, data analysis и другие часто встречающиеся скиллы
Значительно выросли: business intelligence, SSAS, javascript, UNIX, GIS и другие редкие скиллы
